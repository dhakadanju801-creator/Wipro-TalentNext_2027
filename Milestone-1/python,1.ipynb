# %%
a=3
b=4
c=a+b
c
# Out:
# 7

# %%
a=int(input("Enter no"))
b=a/2
print(b)
# Out:
# Enter no 2
# 1.0

# %%
a = int(input("enter first number"))
b=int(input("enter second number"))
print(a+b)
# Out:
# enter first number 12
# enter second number 12
# 24

# %%
name="anju"
age=19
price=26.3
print("my name is:",name)
print("my age is:",age)
print(type(name))
print(type(age))
print(type(price))
# Out:
# my name is: anju
# my age is: 19
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
#sum of two number
a=14
b=17
print(a+b)
print(a-b)
print(a%b)
print(a*b)
# Out:
# 31
# -3
# 14
# 238

# %%
a=23
b=12
a+b
# Out:
# 35

# %%
val1=True
val2=False
print("AND operator:",val1)
print("OR operator:",val2)
# Out:
# AND operator: True
# OR operator: False

# %%
name=str(input("enter your name:"))
age=input("enter the age:")
#print(name)
#print(age)
name
age
# Out:
# enter your name: shivani chimkandi
# enter the age: 999
# '999'

# %%
str1="anju"
print(len(str1))
str2="dhakad"
print(len(str2))
str3=str1+str2
len3=len(str3)
print(len3)
print(str3)
# Out:
# 4
# 6
# 10
# anjudhakad

# %%
str="cricket"
ch=str[2]
print(ch)
print(str[4])
# Out:
# i
# k

# %%
str="rohit cricket"
print(str[ :7])
print(str[1:4])
print(str[3: ])
# Out:
# rohit c
# ohi
# it cricket

# %%
name=input("enter name")
print("length of name:",len(name))
# Out:
# enter name anju
# length of name: 4

# %%
age=13
if(age>=18):
    print("CAN VOTE AND APPLY FOR LICENSE")
else:
    print("CAN NOT VOTE AND NOT APPLY FOR LINCECSE")
# Out:
# CAN NOT VOTE AND NOT APPLY FOR LINCECSE

# %%
light="pink"
if(light=="red"):
    print("stop")
elif(light=="green"):
    print("go")
elif(light=="yellow"):
    print("look")
else:
    print("light is broken")
# Out:
# light is broken

# %%
num=2
if(num>3):
    print("greater than 3")
elif(num<5):
    print("less than 5")
# Out:
# less than 5

# %%
marks=int(input("enter the number:"))
if(marks>=90):
   grade="A"
elif(marks>=80):
   grade="B"
elif(marks>=70):
   grade="C"
else:
    grade="D"
print("grade of the student:",grade)
# Out:
# enter the number: 91
# grade of the student: A

# %%
num=int(input("enter the number:"))
rem=num%2
if(rem==0):
    print("EVEN NUMBER")
else:
    print("ODD NUMBER")
# Out:
# enter the number: 82
# EVEN NUMBER

# %%
a=int(input("enter the first number:"))
b=int(input("enter the second number:"))
c=int(input("enter the third number:"))
if(a>=b and a>=c):
    print("firsr number is largest:",a)
elif(b>=c):
    print("second number is largest:",b)
else:
    print("third number is largest:",c)
# Out:
# enter the first number: 32
# enter the second number: 48
# enter the third number: 92
# third number is largest: 92

# %%
x=5
if(x%7==0):
    print("multiple of 7")
else:
    print("not a multiple of 7")
# Out:
# not a multiple of 7

# %%
marks=[23.4, 45, 67, 78.9, 56, 90]

print(marks)
print(len(marks))
print(type(marks))
print(marks[2]) #call the list element
print(marks[0])
print(marks[4])
# Out:
# [23.4, 45, 67, 78.9, 56, 90]
# 6
# <class 'list'>
# 67
# 23.4
# 56

# %%
student=["arjun",99.9,17,"mumbai"]
print(student)
student[2]=163 #replace the value of list
print(student)
print(student[0])
student[0]="Aman"
print(student)
# Out:
# ['arjun', 99.9, 17, 'mumbai']
# ['arjun', 99.9, 163, 'mumbai']
# arjun
# ['Aman', 99.9, 163, 'mumbai']

# %%
marks=[34,45,67,124,67,69,89]
print(len(marks)) #slicing
print(marks[2:7])
print(marks[ :7])
print(marks[0: ])
print(marks[4:5])
# Out:
# 7
# [67, 124, 67, 69, 89]
# [34, 45, 67, 124, 67, 69, 89]
# [34, 45, 67, 124, 67, 69, 89]
# [67]

# %%
list=[7,4,3,5,2,1]
list.append(6)
list.append(2)
print(list)
#list.sort()
#print(list)
print(list.sort())
print(list)
#list.reverse()
#print(list)
print(list.reverse())
print(list)
list.insert(2,9)
print(list)
list.remove(3)
print(list)
list.pop(4)
print(list)
# Out:
# [7, 4, 3, 5, 2, 1, 6, 2]
# None
# [1, 2, 2, 3, 4, 5, 6, 7]
# None
# [7, 6, 5, 4, 3, 2, 2, 1]
# [7, 6, 9, 5, 4, 3, 2, 2, 1]
# [7, 6, 9, 5, 4, 2, 2, 1]
# [7, 6, 9, 5, 2, 2, 1]

# %%
tup=(12,34,56,47,98,39,67)
print(type(tup))
print(len(tup))
print(tup[0])
print(tup[2])
print(tup[4:])
print(tup[1:6])
# Out:
# <class 'tuple'>
# 7
# 12
# 56
# (98, 39, 67)
# (34, 56, 47, 98, 39)

# %%
tup=(1,2,3,1,4)
print(tup.index(2))
print(tup.count(2))
# Out:
# 1
# 1

# %%
movies=[]
mov1=input("enter 1st movies:")
mov2=input("enter 2nd movies:")
mov3=input("enter 3rd movies:")
movies.append(mov1)
movies.append(mov2)
movies.append(mov3)
print(movies)
# Out:
# enter 1st movies: 3 idot
# enter 2nd movies: gadar
# enter 3rd movies: barish
# ['3 idot', 'gadar', 'barish']

# %%
grade=["C","D","A","B","B","A"]
print(grade.count("A"))
grade.sort()
print(grade)
grade.append("c")
print(grade)
print(type(grade))
print(len(grade))
# Out:
# 2
# ['A', 'A', 'B', 'B', 'C', 'D']
# ['A', 'A', 'B', 'B', 'C', 'D', 'c']
# <class 'list'>
# 7

# %%
dict={
    "name":"anju",
     "cgpa": 9,
     "marks":[98,89,90]
}
print(dict)
# Out:
# {'name': 'anju', 'cgpa': 9, 'marks': [98, 89, 90]}

# %%
info={
    "name": "anju",
    "surname":"Dhakar",
    "age" : 19,
    
    "Cgp" : 9,
    "topices":("dict","set")
}
print(info)
info["name"]="kanak"      #(changeg key)  
info["surname"]="patel"
print(info)
# Out:
# {'name': 'anju', 'surname': 'Dhakar', 'age': 19, 'Cgp': 9, 'topices': ('dict', 'set')}
# {'name': 'kanak', 'surname': 'patel', 'age': 19, 'Cgp': 9, 'topices': ('dict', 'set')}

# %%
null_dict={}
null_dict["name"]="patel sahab"
print(null_dict)
# Out:
# {'name': 'patel sahab'}

# %%
student={
    "name":"anju",
     "score":{
         "physics":98,
         "chemistry":90,
         "english":80,
         "mathematical":99,
     }
}
print(student["score"]["physics"])
print(student["score"]["chemistry"])
print(student["score"]["english"])
print(student["score"]["mathematical"])
# Out:
# 98
# 90
# 80
# 99

# %%
student={
    "name":"anju",
    "subject":{
         "chemistry":90,
         "english":80,
         "mathematical":99,
     }
}
print(len(list(student.keys())))
print(student.keys())
print(list(student.keys()))
# Out:
# 2
# dict_keys(['name', 'subject'])
# ['name', 'subject']

# %%
student={
    "name":"anju",
    "subject":{
         "chemistry":90,
         "english":80,
         "mathematical":99,
     }
}
print(list(student.values()))       #METHOD OF DICT
print(list(student.items()))
print(student.get("name"))
print(student.get("subject"))
student.update({"city":"Delhi"})
print(student)
# Out:
# ['anju', {'chemistry': 90, 'english': 80, 'mathematical': 99}]
# [('name', 'anju'), ('subject', {'chemistry': 90, 'english': 80, 'mathematical': 99})]
# anju
# {'chemistry': 90, 'english': 80, 'mathematical': 99}
# {'name': 'anju', 'subject': {'chemistry': 90, 'english': 80, 'mathematical': 99}, 'city': 'Delhi'}

# %%
set={45,67,78,90,45,"anju","age","bhopal"}
print(set)
print(len(set))
print(type(set))
# Out:
# {'bhopal', 67, 90, 'age', 45, 78, 'anju'}
# 7
# <class 'set'>

# %%
collection = set()
collection.add(14)
collection.add("anju")
collection.add((1,2,3))
collection.add(1)
collection.add("apna college")      #method of set  
collection.add(2)
collection.remove("anju")
#collection.clear()
print(collection)
print(len(collection))
print(type(collection))
# Out:
# {1, 2, (1, 2, 3), 14, 'apna college'}
# 5
# <class 'set'>

# %%
collection={"hellow","apna college","python","bhopal"}
print(collection.pop())
print(collection.pop())
print(len(collection))
# Out:
# hellow
# bhopal
# 2

# %%
set1={1,2,3}
#set2={4,5,6}
set2={2,3,6}
set3=set1.union(set2)
print(set3)
print(set1.union(set2))
print(set1)
print(set2)
print(set1.intersection(set2))
# Out:
# {1, 2, 3, 6}
# {1, 2, 3, 6}
# {1, 2, 3}
# {2, 3, 6}
# {2, 3}

# %%
dictonary={
    "cat":"a small animal",
    "table":["a piece of furniture","list of facts $ figures"]
}
print(dictonary)
# Out:
# {'cat': 'a small animal', 'table': ['a piece of furniture', 'list of facts $ figures']}

# %%
subject={
    "python","java","c++","python","javascript","java","python","java","c++","c",
}
print(subject)
print(len(subject))
# Out:
# {'c++', 'c', 'python', 'javascript', 'java'}
# 5

# %%
marks={}
x=int(input("enter the phy:"))
marks.update({"phy":x})
x=int(input("enter the chem:"))
marks.update({"chem":x})
x=int(input("enter the maths:"))
marks.update({"maths":x})
print(marks)
# Out:
# enter the phy: 80
# enter the chem: 90
# enter the maths: 89
# {'phy': 80, 'chem': 90, 'maths': 89}

# %%
'''value={"9",9.0}
print(value)'''
values={
    "int":9,
    "float":9.0,
}
print(values)
# Out:
# {'int': 9, 'float': 9.0}

# %%
print("END FILE")
# Out:
# END FILE
