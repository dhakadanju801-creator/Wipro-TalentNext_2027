# %% [markdown]
# ### Project - 4:

# %%
# Input string
text = input("Enter a string: ")

# Count occurrences of "Alex"
count = text.count("Alex")

# Display result
print("Alex appears", count, "times.")
# Out:
# Enter a string:  Anju Dhakar
# Alex appears 0 times.
